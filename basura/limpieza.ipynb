# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
original= pd.read_csv("mergeado_final.csv", index_col= 0)

# %%
df = original.copy()

# %%
df.shape
# Out:
# (25973, 261)

# %%
pd.options.display.max_columns=None
df.head(1)
# Out:
#    level_0  index  time    age gender     Q3                 Q4     Q5  \
# 0        0      0   910  50-54    Man  India  Bachelor’s degree  Other
#
#            Q6      Q8       Q11        Q13         Q15  \
# 0  5-10 years  Python  A laptop  2-5 times  5-10 years
#
#                          Q20               Q21  Q22  \
# 0  Manufacturing/Fabrication  50-249 employees  3-4
#
#                              Q23            Q25        Q26  Q33  Q35  \
# 0  No (we do not use ML methods)  25,000-29,999  $100-$999  NaN  NaN
#
#                                                  Q41         Q7            Q9  \
# 0  Local development environments (RStudio, Jupyt...  Python, R   Vim / Emacs
#
#                   Q12                                                Q14  \
# 0  Google Cloud TPUs    Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# ...

# %%
df_limpios= df.drop(["level_0","time","Q11","Q13","Q15","Q26","Q9","Q12","Q14",], axis=1)
df_limpios.shape
# Out:
# (25973, 252)

# %%
df_limpios2= df_limpios.drop(["Q16","Q17","Q24","Q10_Part_1", "Q10_Part_2", "Q10_Part_3", "Q10_Part_4", "Q10_Part_5", \
    "Q10_Part_6", "Q10_Part_7",	"Q10_Part_8", "Q10_Part_9",	"Q10_Part_10", "Q10_Part_11", "Q10_Part_12", "Q10_Part_13",\
    "Q10_Part_14", "Q10_Part_15", "Q10_Part_16", "Q10_OTHER"], axis=1) 
    ##seguir revisando a partir de: Unnamed: 0.1 Q18_Part_1

# %%
df_limpios2.shape
# Out:
# (25973, 232)

# %%
lista=list(df.columns)
lista
# Out:
# ['level_0',
#  'index',
#  'time',
#  'age',
#  'gender',
#  'Q3',
#  'Q4',
#  'Q5',
#  'Q6',
#  'Q8',
#  'Q11',
#  'Q13',
#  'Q15',
#  'Q20',
#  'Q21',
#  'Q22',
#  'Q23',
#  'Q25',
#  'Q26',
#  'Q33',
#  'Q35',
#  'Q41',
#  'Q7',
#  'Q9',
#  'Q12',
#  'Q14',
#  'Q16',
#  'Q17',
#  'Q24',
#  'Q32',
#  'Q34',
#  'Q10_Part_1',
#  'Q10_Part_2',
#  'Q10_Part_3',
#  'Q10_Part_4',
#  'Q10_Part_5',
#  'Q10_Part_6',
#  'Q10_Part_7',
#  'Q10_Part_8',
#  'Q10_Part_9',
#  'Q10_Part_10',
#  'Q10_Part_11',
#  'Q10_Part_12',
#  'Q10_Part_13',
#  'Q10_Part_14',
#  'Q10_Part_15',
#  'Q10_Part_16',
#  'Q10_OTHER',
#  'Unnamed: 0.1',
#  'Q18_Part_1',
#  'Q18_Part_2',
#  'Q18_Part_3',
#  'Q18_Part_4',
#  'Q18_Part_5',
#  'Q18_Part_6',
#  'Q18_OTHER',
#  'Q19_Part_1',
#  'Q19_Part_2',
#  'Q19_Part_3',
#  'Q19_Part_4',
#  'Q19_Part_5',
#  'Q19_OTHER',
#  'Q27_A_Part_1',
#  'Q27_A_Part_2',
#  'Q27_A_Part_3',
#  'Q27_A_Part_4',
#  'Q27_A_Part_5',
#  'Q27_A_Part_6',
#  'Q27_A_Part_7',
#  'Q27_A_Part_8',
# ...

# %%
df_limpios3 = df_limpios2.drop(['Unnamed: 0.1', 'Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3', 'Q27_A_Part_4', 'Q27_A_Part_5', 'Q27_A_Part_6', 'Q27_A_Part_7',\
'Q27_A_Part_8', 'Q27_A_Part_9',  'Q28', 'Q42_Part_1', 'Q42_Part_2', 'Q42_Part_3', 'Q42_Part_4', 'Q28',  'Q42_Part_5', 'Q42_Part_6', 'Q42_Part_7',
'Q42_Part_8', 'Q42_Part_9', 'Q42_Part_10', 'Q42_Part_11', 'Q42_OTHER'],axis=1)

# %%
df_limpios3.columns
# Out:
# Index(['index', 'age', 'gender', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q20', 'Q21',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=209)

# %%
df_limpios3.to_csv('df_columnas.csv')

# %%
df = pd.read_csv('df_columnas.csv', index_col=0)

# %%
df.head(2)
# Out:
#    index    age gender         Q3                 Q4                       Q5  \
# 0      0  50-54    Man      India  Bachelor’s degree                    Other
# 1      1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
#
#            Q6      Q8                        Q20                   Q21  Q22  \
# 0  5-10 years  Python  Manufacturing/Fabrication      50-249 employees  3-4
# 1   20+ years  Python  Manufacturing/Fabrication  1000-9,999 employees  1-2
#
#                                                  Q23            Q25  Q33  Q35  \
# 0                      No (we do not use ML methods)  25,000-29,999  NaN  NaN
# 1  We are exploring ML methods (and may one day p...  60,000-69,999  NaN  NaN
#
#                                                  Q41                  Q7  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
# ...

# %%
df.rename(columns = {'Q3':'pais', 'Q4':'nivel_educativo', 'Q5':'puesto_actual', 'Q6':'experiencia_program', 'Q40':'plataformas_cursos', 'Q20':'sector_actual', 'Q21':'tamaño_empresa', 'Q22':'equipo_data_tamaño', 'Q25':'salario_anual'}, inplace = True)

# %% [markdown]
#  HAY QUE ELIMINAR COLUMNA 33 y 35

# %%
df.rename(columns = {'Q8':'lenguaje_recomendado_inic', 'Q23':'ML_uso', 'Q34':'IE_usos', 'Q41':'DA_usos', 'Q7':'lenguajes_habitual', 'Q32':'BD_usos'}, inplace=True)

# %%
df.isnull().sum().loc['Q34']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q34'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.drop(columns=['Q33', 'Q35'], axis=1, inplace=True)

# %%
df.to_csv('df_columnas_nuevas.csv')

# %%
df.head(2)
# Out:
#    index    age gender       pais    nivel_educativo            puesto_actual  \
# 0      0  50-54    Man      India  Bachelor’s degree                    Other
# 1      1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
#
#   experiencia_program lenguaje_recomendado_inic              sector_actual  \
# 0          5-10 years                    Python  Manufacturing/Fabrication
# 1           20+ years                    Python  Manufacturing/Fabrication
#
#          tamaño_empresa equipo_data_tamaño  \
# 0      50-249 employees                3-4
# 1  1000-9,999 employees                1-2
#
#                                               ML_uso  salario_anual  \
# 0                      No (we do not use ML methods)  25,000-29,999
# 1  We are exploring ML methods (and may one day p...  60,000-69,999
#
#                                              DA_usos  lenguajes_habitual  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# ...

# %%
df.head(1)
# Out:
#    index    age gender   pais    nivel_educativo puesto_actual  \
# 0      0  50-54    Man  India  Bachelor’s degree         Other
#
#   experiencia_program lenguaje_recomendado_inic              sector_actual  \
# 0          5-10 years                    Python  Manufacturing/Fabrication
#
#      tamaño_empresa equipo_data_tamaño                         ML_uso  \
# 0  50-249 employees                3-4  No (we do not use ML methods)
#
#    salario_anual                                            DA_usos  \
# 0  25,000-29,999  Local development environments (RStudio, Jupyt...
#
#   lenguajes_habitual       BD_usos IE_usos  \
# 0          Python, R   PostgreSQL     None
#
#                                           Q18_Part_1 Q18_Part_2 Q18_Part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
#
#   Q18_Part_4 Q18_Part_5 Q18_Part_6 Q18_OTHER  \
# 0        NaN        NaN        NaN       NaN
#
# ...

# %%
a = df_limpios3[['Q29_A_Part_1', 'Q29_A_Part_2', 'Q29_A_Part_3', 'Q29_A_Part_4', 'Q29_A_OTHER']]
a
# Out:
#                                Q29_A_Part_1  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 25968   Amazon Elastic Compute Cloud (EC2)
# 25969                                   NaN
# 25970                                   NaN
# 25971                                   NaN
# 25972                                   NaN
#
#                              Q29_A_Part_2                   Q29_A_Part_3  \
# 0                                     NaN   Google Cloud Compute Engine
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# ...

# %%
a=a.fillna("NAN")
a=a.astype('str')
a["union"] = a[['Q29_A_Part_1', 'Q29_A_Part_2', 'Q29_A_Part_3', 'Q29_A_Part_4', 'Q29_A_OTHER']].agg(','.join, axis=1)
a['union'] = a['union'].str.replace('NAN,', '')
a['union'] = a['union'].str.replace(',NAN', '')
a['union'] = a['union'].apply(lambda x: x.split(','))

# %%
a['union'][25968][0]
# Out:
# ' Amazon Elastic Compute Cloud (EC2) '

# %%
a = a.explode('union')

# %%
a['union'].unique()
# Out:
# array([' Google Cloud Compute Engine ', 'NAN',
#        ' Microsoft Azure Virtual Machines ', 'No / None',
#        ' Amazon Elastic Compute Cloud (EC2) ', 'Other'], dtype=object)

# %%
a= a.apply(lambda x: x.replace('NAN', np.nan))

# %%
a.dropna(how='all', inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.countplot(data= a, x='union')
# Out:
# <AxesSubplot:xlabel='union', ylabel='count'>

# %%
plt.figure()
plt.pie(c["count"], labels =c["top"], colors = ["lightseagreen", "lightcoral", "lightskyblue", "mediumorchid", "yellow"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20690/1607204942.py in <module>
#       1 plt.figure()
# ----> 2 plt.pie(c["count"], labels =c["top"], colors = ["lightseagreen", "lightcoral", "lightskyblue", "mediumorchid", "yellow"])
#       3 plt.show()
#
# NameError: name 'c' is not defined

# %%
b = a['Q29_A_Part_1'].value_counts()
a['Q29_A_Part_2'].value_counts()
a['Q29_A_Part_3'].value_counts()
a['Q29_A_Part_4'].value_counts()
a['Q29_A_OTHER'].value_counts()
# Out:
# Other    145
# Name: Q29_A_OTHER, dtype: int64

# %%
c = a.describe(include="object").T
c
# Out:
#              count unique                                   top  freq
# Q29_A_Part_1  3449      1   Amazon Elastic Compute Cloud (EC2)   3449
# Q29_A_Part_2  2523      1     Microsoft Azure Virtual Machines   2523
# Q29_A_Part_3  3114      1          Google Cloud Compute Engine   3114
# Q29_A_Part_4  1795      1                             No / None  1795
# Q29_A_OTHER    145      1                                 Other   145
# union         7626      5   Amazon Elastic Compute Cloud (EC2)   2270

# %%
Amazon  = a.agg(frecuencia=('count', "count"))

Amazon
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_20690/3519815394.py in <module>
# ----> 1 Amazon  = a.agg(frecuencia=('count', "count"))
#       2
#       3 Amazon
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in aggregate(self, func, axis, *args, **kwargs)
#    8548
#    8549         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 8550         result = op.agg()
#    8551
#    8552         if relabeling:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#     698         result = None
#     699         try:
# --> 700             result = super().agg()
#     701         except TypeError as err:
#     702             exc = TypeError(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#     159
#     160         if is_dict_like(arg):
# ...

# %%
plt.figure(figsize = (10,5))

plt.hist(c["top"])
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize =(8,4))
sns.pairplot(data = c, hue = "top")
plt.show()

# %%
c
# Out:
#              count unique                                   top  freq
# Q29_A_Part_1  2270      1   Amazon Elastic Compute Cloud (EC2)   2270
# Q29_A_Part_2  1503      1     Microsoft Azure Virtual Machines   1503
# Q29_A_Part_3  1960      1          Google Cloud Compute Engine   1960
# Q29_A_Part_4  1795      1                             No / None  1795
# Q29_A_OTHER     98      1                                 Other    98

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
#antoanela
df=df.fillna("NAN")
df=df.astype('str')
df["Q37A"] = df[['Q37_A_Part_1', 'Q37_A_Part_2', 'Q37_A_Part_3', 'Q37_A_Part_4', 'Q37_A_Part_5', 'Q37_A_Part_6','Q37_A_Part_7', 'Q37_A_OTHER']].agg(','.join, axis=1)
df['Q37A'] = df['Q37A'].str.replace('NAN,', '')
df['Q37A'] = df['Q37A'].str.replace(',NAN', '')
df['Q37A'] = df['Q37A'].apply(lambda x: x.split(','))

# %%
df = df.explode('Q37A')

# %%
df['Q37A'].unique()
# Out:
# array([nan, ' Databricks AutoML ', ' H2O Driverless AI  ',
#        ' Google Cloud AutoML ', 'No / None',
#        '  Amazon Sagemaker Autopilot ', 'Other', ' DataRobot AutoML ',
#        '  Azure Automated Machine Learning '], dtype=object)

# %%
df= df.apply(lambda x: x.replace('NAN', np.nan))

# %%
df.dropna(how='all', inplace=True)

# %%
df=df.fillna("NAN")
df=df.astype('str')
df["Q38A"] = df[['Q38_A_Part_1', 'Q38_A_Part_2', 'Q38_A_Part_3', 'Q38_A_Part_4', 'Q38_A_Part_5', 'Q38_A_Part_6','Q38_A_Part_7', 'Q38_A_Part_8', 'Q38_A_Part_9', 'Q38_A_Part_10', 'Q38_A_Part_11', 'Q38_A_OTHER']].agg(','.join, axis=1)
df['Q38A'] = df['Q38A'].str.replace('NAN,', '')
df['Q38A'] = df['Q38A'].str.replace(',NAN', '')
df['Q38A'] = df['Q38A'].apply(lambda x: x.split(','))

# %%
df = df.explode('Q38A')

# %%
df['Q38A'].unique()
# Out:
# array(["['No / None']", "['NAN']", "[' Weights & Biases ']",
#        "[' MLflow ']", "[' Weights & Biases ', ' TensorBoard ']",
#        "[' TensorBoard ', ' MLflow ']", "['Other']",
#        "[' Domino Model Monitor ', ' MLflow ']", "[' Neptune.ai ']",
#        "[' TensorBoard ']", "[' Neptune.ai ', ' ClearML ', ' MLflow ']",
#        "[' Neptune.ai ', ' Comet.ml ', ' TensorBoard ', ' MLflow ']",
#        "[' Weights & Biases ', ' MLflow ']",
#        "[' Neptune.ai ', ' MLflow ']", "[' Guild.ai ']",
#        "[' TensorBoard ', ' Domino Model Monitor ']",
#        "[' Neptune.ai ', ' Weights & Biases ', ' Sacred + Omniboard ', ' Polyaxon ', ' MLflow ']",
#        "[' Weights & Biases ', ' Polyaxon ', ' MLflow ']",
#        "[' Guild.ai ', ' Polyaxon ', ' MLflow ']",
#        "[' TensorBoard ', ' ClearML ', ' MLflow ']", "[' ClearML ']",
#        "[' Comet.ml ']",
# ...

# %%
df= df.apply(lambda x: x.replace('NAN', np.nan))

# %%
df.dropna(how='all', inplace=True)

# %%
df=df.fillna("NAN")
df=df.astype('str')
df["Q39"] = df[['Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_4', 'Q39_Part_5', 'Q39_Part_6','Q39_Part_7', 'Q39_Part_8', 'Q39_Part_9', 'Q39_OTHER']].agg(','.join, axis=1)
df['Q39'] = df['Q39'].str.replace('NAN,', '')
df['Q39'] = df['Q39'].str.replace(',NAN', '')
df['Q39'] = df['Q39'].apply(lambda x: x.split(','))

# %%
df = df.explode('Q39')

# %%
df['Q39'].unique()
# Out:
# array([' GitHub ', ' Kaggle ', 'NAN', 'I do not share my work publicly',
#        ' Plotly Dash ', ' Colab ', 'Other', ' Streamlit ',
#        ' Personal blog ', ' NBViewer ', ' Shiny '], dtype=object)

# %%
df= df.apply(lambda x: x.replace('NAN', np.nan))

# %%
df.dropna(how='all', inplace=True)

# %%
df.head(1)
# Out:
#   index    age gender   pais    nivel_educativo puesto_actual  \
# 0     0  50-54    Man  India  Bachelor’s degree         Other
#
#   experiencia_program lenguaje_recomendado_inic              sector_actual  \
# 0          5-10 years                    Python  Manufacturing/Fabrication
#
#      tamaño_empresa equipo_data_tamaño                         ML_uso  \
# 0  50-249 employees                3-4  No (we do not use ML methods)
#
#    salario_anual                                            DA_usos  \
# 0  25,000-29,999  Local development environments (RStudio, Jupyt...
#
#   lenguajes_habitual       BD_usos IE_usos  \
# 0          Python, R   PostgreSQL     None
#
#                                           Q18_Part_1 Q18_Part_2 Q18_Part_3  \
# 0  General purpose image/video tools (PIL, cv2, s...        NaN        NaN
#
#   Q18_Part_4 Q18_Part_5 Q18_Part_6 Q18_OTHER  \
# 0        NaN        NaN        NaN       NaN
#
# ...

# %%
df=df.fillna("NAN")
df=df.astype('str')
df["Q40"] = df[['Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3', 'Q40_Part_4', 'Q40_Part_5', 'Q40_Part_6','Q40_Part_7', 'Q40_Part_8', 'Q40_Part_9', 'Q40_Part_10', 'Q40_Part_11', 'Q40_OTHER']].agg(','.join, axis=1)
df['Q40'] = df['Q40'].str.replace('NAN,', '')
df['Q40'] = df['Q40'].str.replace(',NAN', '')
df['Q40'] = df['Q40'].apply(lambda x: x.split(','))

# %%
df = df.explode('Q40')

# %%
df['Q40'].unique()
# Out:
# array(['Coursera', 'edX', 'Kaggle Learn Courses', 'DataCamp', 'Udacity',
#        'Udemy', 'Cloud-certification programs (direct from AWS', ' Azure',
#        ' GCP', ' or similar)',
#        'University Courses (resulting in a university degree)', 'NAN',
#        'LinkedIn Learning', 'None', 'Other', 'Fast.ai'], dtype=object)

# %%
df= df.apply(lambda x: x.replace('NAN', np.nan))

# %%
df.dropna(how='all', inplace=True)
